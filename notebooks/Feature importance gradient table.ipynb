# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
def get_exp_path(expid):
    expid = str(expid)
    logs_folder = Path(r"C:\Users\Mathiass\Documents\Projects\master-thesis")/"logs"
    matches = Path(logs_folder).rglob(expid) #Get folder in logs_folder that matches expid
    matches_list = list(matches)
    if not len(matches_list) == 1:
        raise ValueError(f"There exists none or more than 1 folder with "
                            f"experiment id {expid} in the {logs_folder.name} "
                            "directory!")
    exp_dir = matches_list[0]
    return exp_dir

# %%
def load_df(expid_path, metric):
    if metric == "balacc":
        imp_path = expid_path/"results/importance_full/balaccmeandiff_sorted.csv"
        print("Reading", imp_path.name, "...")
        imp_df = pd.read_csv(imp_path, index_col=0, header=1, usecols=["Unnamed: 0", "MeanDiffOrigPerm"])
    elif metric == "return":
        imp_path = expid_path/"results/importance_full/meanofmeandiffpf_sorted.csv"
        print("Reading", imp_path.name, "...")
        imp_df = pd.read_csv(imp_path, index_col=0, header=1, usecols=["Unnamed: 0", "MomDiff"])
    else:
        raise NotImplementedError("Please specify a valid metric.")
    return imp_df

# %%
# def sum_ranks(expid_ls):
#     count_dic = {}
#     for expid in expid_ls:
#         p = get_exp_path(expid)
#         print("Model:", p.parent.parent.name,",", p.parent.name)
#         df = load_df(p, metric="balacc")
#         df_dic = {k: v for v, k in list(enumerate(df.index))}
# #         print(df_dic)
#         count_dic = {key: count_dic.get(key, 0) + df_dic.get(key, 0) for key in df_dic}
#     return count_dic

# %%
def gradient_table(expid_ls, metric):
    counts = {}
    ls_df = []
    for expid in expid_ls:
        p = get_exp_path(expid)
        print("Model:", p.parent.parent.name,",", p.parent.name)
        df = load_df(p, metric=metric)
        df.columns = [p.parent.name]
        ls_df.append(df)
        df_dic = {k: v for v, k in list(enumerate(df.index))}
        print(df_dic)
        counts = {key: counts.get(key, 0) + df_dic.get(key, 0) for key in df_dic}
    counts_sorted = {k: v for k, v in sorted(counts.items(), key=lambda item: item[1])}
    print("---")
    print("Counts added and sorted:", counts_sorted)
    for i in range(len(ls_df)):
        print(ls_df[i])
        ls_df[i] = ls_df[i].reindex(list(counts_sorted))
#     print(ls_df)
    return pd.concat(ls_df, axis=1)

# %%
def return_grad_tables(features, metric_ls):
    feature_expid_map = {"option": [20220919194922, 20220919213409, 20220919200811, 20220908133630, 20220915074003],
                        "option+stock": [20220922192602, 20220923123700, 20220924104656, 20220920100736, 20220923074741]}
    grad_tables = {}
    for f in features:
        expid_ls = feature_expid_map[f]
        for m in metric_ls:
            grad_tables[f+"_"+m] = gradient_table(expid_ls, m).style.background_gradient(axis=0)
    return grad_tables

# %% [markdown]
# ### 1. Specify feature set

# %%
features = ["option", "option+stock"]

# %% [markdown]
# ### 2. Specfiy metric

# %%
metrics = ["balacc", "return"]

# %% [markdown]
# ### 3. Produce tables.

# %%
# ls_df = gradient_table(expid_ls, metric=metric)
grad_tables = return_grad_tables(features, metrics)
# Out:
# Model: small , lin
# Reading balaccmeandiff_sorted.csv ...
# {'delta': 0, 'gamma': 1, 'impl_volatility': 2, 'days_to_exp': 3, 'moneyness': 4, 'theta': 5, 'vega': 6, 'ba_spread_option': 7, 'volume': 8, 'mid_price': 9, 'open_interest': 10}
# Model: small , rf
# Reading balaccmeandiff_sorted.csv ...
# {'moneyness': 0, 'impl_volatility': 1, 'theta': 2, 'delta': 3, 'gamma': 4, 'days_to_exp': 5, 'vega': 6, 'volume': 7, 'open_interest': 8, 'ba_spread_option': 9, 'mid_price': 10}
# Model: small , xgb
# Reading balaccmeandiff_sorted.csv ...
# {'impl_volatility': 0, 'moneyness': 1, 'delta': 2, 'theta': 3, 'gamma': 4, 'days_to_exp': 5, 'mid_price': 6, 'vega': 7, 'ba_spread_option': 8, 'open_interest': 9, 'volume': 10}
# Model: small , nn
# Reading balaccmeandiff_sorted.csv ...
# {'impl_volatility': 0, 'delta': 1, 'days_to_exp': 2, 'theta': 3, 'gamma': 4, 'moneyness': 5, 'vega': 6, 'ba_spread_option': 7, 'volume': 8, 'open_interest': 9, 'mid_price': 10}
# Model: small , transformer
# Reading balaccmeandiff_sorted.csv ...
# {'delta': 0, 'impl_volatility': 1, 'vega': 2, 'days_to_exp': 3, 'gamma': 4, 'theta': 5, 'moneyness': 6, 'ba_spread_option': 7, 'volume': 8, 'open_interest': 9, 'mid_price': 10}
# ---
# Counts added and sorted: {'impl_volatility': 4, 'delta': 6, 'moneyness': 16, 'gamma': 17, 'days_to_exp': 18, 'theta': 18, 'vega': 27, 'ba_spread_option': 38, 'volume': 41, 'open_interest': 45, 'mid_price': 45}
#                        lin
# delta             0.056867
# gamma             0.028654
# impl_volatility   0.025447
# days_to_exp       0.012666
# moneyness         0.010346
# theta             0.007559
# vega              0.004896
# ba_spread_option  0.002154
# volume            0.000668
# mid_price         0.000394
# open_interest    -0.000206
#                         rf
# moneyness         0.033881
# impl_volatility   0.032502
# theta             0.014953
# delta             0.013684
# gamma             0.011254
# days_to_exp       0.000425
# vega              0.000210
# volume            0.000000
# open_interest     0.000000
# ba_spread_option -0.000004
# mid_price        -0.000234
#                        xgb
# impl_volatility   0.074364
# moneyness         0.056345
# delta             0.023263
# theta             0.016632
# gamma             0.007726
# days_to_exp       0.007475
# mid_price         0.006656
# vega              0.004442
# ba_spread_option  0.003007
# open_interest     0.000221
# volume            0.000083
#                         nn
# impl_volatility   0.087455
# delta             0.081589
# days_to_exp       0.021590
# theta             0.014486
# gamma             0.011258
# moneyness         0.007381
# vega              0.005570
# ba_spread_option  0.002987
# volume           -0.000102
# open_interest    -0.000125
# mid_price        -0.002198
#                   transformer
# delta                0.117383
# impl_volatility      0.103091
# vega                 0.033121
# days_to_exp          0.031428
# gamma                0.020853
# theta                0.014584
# moneyness            0.012716
# ba_spread_option     0.001815
# volume               0.000218
# open_interest        0.000092
# mid_price           -0.001941
# Model: small , lin
# Reading meanofmeandiffpf_sorted.csv ...
# {'impl_volatility': 0, 'days_to_exp': 1, 'delta': 2, 'moneyness': 3, 'volume': 4, 'open_interest': 5, 'theta': 6, 'mid_price': 7, 'ba_spread_option': 8, 'vega': 9, 'gamma': 10}
# Model: small , rf
# Reading meanofmeandiffpf_sorted.csv ...
# {'gamma': 0, 'impl_volatility': 1, 'theta': 2, 'days_to_exp': 3, 'ba_spread_option': 4, 'volume': 5, 'open_interest': 6, 'vega': 7, 'delta': 8, 'mid_price': 9, 'moneyness': 10}
# Model: small , xgb
# Reading meanofmeandiffpf_sorted.csv ...
# {'impl_volatility': 0, 'days_to_exp': 1, 'ba_spread_option': 2, 'theta': 3, 'gamma': 4, 'delta': 5, 'moneyness': 6, 'volume': 7, 'open_interest': 8, 'mid_price': 9, 'vega': 10}
# Model: small , nn
# Reading meanofmeandiffpf_sorted.csv ...
# {'days_to_exp': 0, 'ba_spread_option': 1, 'impl_volatility': 2, 'vega': 3, 'mid_price': 4, 'gamma': 5, 'moneyness': 6, 'theta': 7, 'volume': 8, 'open_interest': 9, 'delta': 10}
# Model: small , transformer
# Reading meanofmeandiffpf_sorted.csv ...
# {'days_to_exp': 0, 'impl_volatility': 1, 'delta': 2, 'gamma': 3, 'moneyness': 4, 'theta': 5, 'ba_spread_option': 6, 'open_interest': 7, 'volume': 8, 'vega': 9, 'mid_price': 10}
# ---
# Counts added and sorted: {'impl_volatility': 4, 'days_to_exp': 5, 'ba_spread_option': 21, 'gamma': 22, 'theta': 23, 'delta': 27, 'moneyness': 29, 'volume': 32, 'open_interest': 35, 'vega': 38, 'mid_price': 39}
#                        lin
# impl_volatility   0.001723
# days_to_exp       0.001372
# delta             0.000663
# moneyness         0.000077
# volume            0.000076
# open_interest    -0.000022
# theta            -0.000102
# mid_price        -0.000112
# ba_spread_option -0.000160
# vega             -0.000317
# gamma            -0.000399
#                             rf
# gamma             7.788025e-04
# impl_volatility   3.392848e-04
# theta             3.246444e-04
# days_to_exp       4.614259e-05
# ba_spread_option  4.414037e-05
# volume           -5.302304e-18
# open_interest    -5.302304e-18
# vega             -1.244854e-05
# delta            -5.383662e-04
# mid_price        -5.514849e-04
# moneyness        -2.011196e-03
#                        xgb
# impl_volatility   0.001426
# days_to_exp       0.001259
# ba_spread_option  0.001032
# theta             0.000882
# gamma             0.000861
# delta             0.000759
# moneyness         0.000738
# volume            0.000031
# open_interest    -0.000050
# mid_price        -0.000165
# vega             -0.000165
#                         nn
# days_to_exp       0.002352
# ba_spread_option  0.001032
# impl_volatility   0.000984
# vega              0.000876
# mid_price         0.000533
# gamma             0.000487
# moneyness         0.000393
# theta             0.000310
# volume            0.000213
# open_interest    -0.000125
# delta            -0.000393
#                   transformer
# days_to_exp          0.003020
# impl_volatility      0.001811
# delta                0.001406
# gamma                0.001185
# moneyness            0.000725
# theta                0.000457
# ba_spread_option     0.000365
# open_interest        0.000011
# volume              -0.000005
# vega                -0.000098
# mid_price           -0.000213
# Model: medium , lin
# Reading balaccmeandiff_sorted.csv ...
#                       lin
# delta            0.059690
# impl_volatility  0.023419
# gamma            0.022393
# theta            0.017270
# days_to_exp      0.005923
# ...                   ...
# dolvol          -0.001718
# chmom           -0.001827
# idiovol         -0.001839
# mom12m          -0.004938
# baspread        -0.006035
#
# [105 rows x 1 columns]
#                        rf
# moneyness        0.035664
# impl_volatility  0.018053
# delta            0.010410
# baspread         0.007398
# theta            0.002853
# ...                   ...
# dy              -0.000051
# beta            -0.000055
# indmom          -0.000084
# turn            -0.000282
# idiovol         -0.000526
#
# [105 rows x 1 columns]
#                       xgb
# impl_volatility  0.082753
# moneyness        0.065827
# turn             0.016643
# theta            0.015070
# delta            0.011465
# ...                   ...
# cinvest         -0.000288
# idiovol         -0.000334
# chempia         -0.000339
# maxret          -0.000412
# dolvol          -0.001447
#
# [105 rows x 1 columns]
#                        nn
# delta            0.054998
# impl_volatility  0.051406
# theta            0.028829
# moneyness        0.019148
# gamma            0.010885
# ...                   ...
# chempia         -0.000406
# rd_sale         -0.000775
# pchcapx_ia      -0.000956
# indmom          -0.001491
# mvel1           -0.002855
#
# [105 rows x 1 columns]
#                  transformer
# impl_volatility     0.098060
# delta               0.083234
# gamma               0.020148
# moneyness           0.015342
# theta               0.014689
# ...                      ...
# tb                 -0.000429
# mvel1              -0.000507
# chempia            -0.000538
# stdcf              -0.000702
# rd_sale            -0.000886
#
# [105 rows x 1 columns]
# Model: medium , lin
# Reading meanofmeandiffpf_sorted.csv ...
# {'tang': 0, 'theta': 1, 'stdacc': 2, 'days_to_exp': 3, 'chempia': 4, 'impl_volatility': 5, 'delta': 6, 'saleinv': 7, 'mom6m': 8, 'betasq': 9, 'chcsho': 10, 'age': 11, 'mid_price': 12, 'gma': 13, 'mvel1': 14, 'roavol': 15, 'cash': 16, 'nincr': 17, 'aeavol': 18, 'divo': 19, 'cfp': 20, 'roic': 21, 'open_interest': 22, 'secured': 23, 'egr': 24, 'baspread': 25, 'pchsale_pchxsga': 26, 'agr': 27, 'herf': 28, 'sin': 29, 'rd': 30, 'mom12m': 31, 'rd_sale': 32, 'retvol': 33, 'quick': 34, 'ps': 35, 'pchgm_pchsale': 36, 'realestate': 37, 'orgcap': 38, 'cinvest': 39, 'ba_spread_option': 40, 'mom1m': 41, 'ill': 42, 'bm': 43, 'lev': 44, 'chinv': 45, 'roaq': 46, 'stdcf': 47, 'zerotrade': 48, 'chpmia': 49, 'volume': 50, 'ear': 51, 'vega': 52, 'chatoia': 53, 'salecash': 54, 'idiovol': 55, 'divi': 56, 'salerec': 57, 'mom36m': 58, 'std_turn': 59, 'chtx': 60, 'pchquick': 61, 'pricedelay': 62, 'convind': 63, 'dy': 64, 'rsup': 65, 'pchsale_pchinvt': 66, 'ms': 67, 'pchsale_pchrect': 68, 'lgr': 69, 'pchdepr': 70, 'cashpr': 71, 'absacc': 72, 'std_dolvol': 73, 'tb': 74, 'pctacc':
# Counts added and sorted: {'impl_volatility': 11, 'days_to_exp': 16, 'baspread': 39, 'theta': 39, 'mom12m': 65, 'mom1m': 96, 'ba_spread_option': 108, 'delta': 129, 'tang': 136, 'retvol': 136, 'mvel1': 143, 'turn': 144, 'dolvol': 144, 'roic': 145, 'gamma': 171, 'mve_ia': 178, 'mom36m': 179, 'maxret': 183, 'chmom': 189, 'agr': 202, 'idiovol': 205, 'chcsho': 206, 'age': 207, 'beta': 211, 'mid_price': 215, 'realestate': 217, 'chpmia': 219, 'herf': 219, 'mom6m': 220, 'stdcf': 220, 'open_interest': 220, 'ps': 221, 'gma': 222, 'chatoia': 230, 'cashdebt': 231, 'stdacc': 231, 'bm_ia': 231, 'cfp': 237, 'dy': 238, 'pchquick': 241, 'aeavol': 243, 'betasq': 248, 'acc': 253, 'operprof': 254, 'salerec': 256, 'quick': 259, 'pricedelay': 259, 'chempia': 259, 'sgr': 261, 'vega': 266, 'roaq': 266, 'divo': 268, 'pchgm_pchsale': 268, 'cashpr': 270, 'chinv': 273, 'nincr': 274, 'saleinv': 275, 'roavol': 277, 'rd_sale': 278, 'grcapx': 281, 'pchsale_pchxsga': 281, 'egr': 281, 'cash': 282, 'std_dolvol': 288, 'volume': 290, 'lgr': 297, 'ill': 298, 'cfp_ia': 298, 'secured': 298, 'absacc': 299, 'bm': 299, 'rd_mve': 303, 'moneyness': 304, 'pchsale_pchrect': 306, 'grltnoa': 314, 'sin': 315, 'rd': 320, 'hire': 321, 'currat': 321, 'ep': 321, 'orgcap': 324, 'pchsaleinv': 330, 'lev': 330, 'depr': 334, 'pchsale_pchinvt': 340, 'indmom': 342, 'divi': 345, 'ms': 349, 'chtx': 353, 'rsup': 354, 'pctacc': 356, 'pchdepr': 361, 'ear': 364, 'cinvest': 365, 'tb': 365, 'invest': 365, 'zerotrade': 366, 'pchcapx_ia': 378, 'pchcurrat': 378, 'securedind': 381, 'salecash': 382, 'convind': 389, 'roeq': 403, 'std_turn': 411, 'sp': 417}
#                   lin
# tang         0.000612
# theta        0.000606
# stdacc       0.000586
# days_to_exp  0.000484
# chempia      0.000414
# ...               ...
# chmom       -0.000454
# maxret      -0.000478
# depr        -0.000543
# sgr         -0.000633
# gamma       -0.001927
#
# [105 rows x 1 columns]
#                        rf
# baspread         0.000781
# gamma            0.000506
# impl_volatility  0.000331
# retvol           0.000244
# delta            0.000237
# ...                   ...
# std_turn        -0.000022
# betasq          -0.000022
# idiovol         -0.000064
# mid_price       -0.000717
# moneyness       -0.000731
#
# [105 rows x 1 columns]
#                       xgb
# theta            0.001373
# impl_volatility  0.001338
# baspread         0.001108
# days_to_exp      0.001066
# moneyness        0.000993
# ...                   ...
# convind         -0.000014
# sin             -0.000025
# salecash        -0.000045
# lev             -0.000059
# vega            -0.000099
#
# [105 rows x 1 columns]
#                         nn
# theta             0.001629
# impl_volatility   0.001424
# days_to_exp       0.001311
# ba_spread_option  0.000895
# mom12m            0.000710
# ...                    ...
# volume           -0.000155
# pchcapx_ia       -0.000162
# rd_sale          -0.000175
# moneyness        -0.000275
# delta            -0.000543
#
# [105 rows x 1 columns]
#                  transformer
# days_to_exp         0.002751
# baspread            0.002440
# impl_volatility     0.002432
# mom6m               0.001710
# vega                0.001579
# ...                      ...
# lev                -0.000272
# convind            -0.000312
# secured            -0.000377
# indmom             -0.000420
# std_turn           -0.000619
#
# [105 rows x 1 columns]

# %%
grad_tables
# Out:
# {'option_balacc': <pandas.io.formats.style.Styler at 0x1c0e7e20940>,
#  'option_return': <pandas.io.formats.style.Styler at 0x1c0e8d5e1f0>,
#  'option+stock_balacc': <pandas.io.formats.style.Styler at 0x1c0e7e20b50>,
#  'option+stock_return': <pandas.io.formats.style.Styler at 0x1c0e8664130>}

# %%
# with open("Thesis_gradienttable".txt", "w") as text_file:
#     text_file.write(grad_tables["option+stock_balacc"].to_latex(convert_css=True))

# %%
grad_tables["option+stock_balacc"]
# Out:
# <style type="text/css">
# #T_9212c_row0_col0 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_9212c_row0_col1 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_9212c_row0_col2, #T_9212c_row0_col4, #T_9212c_row1_col0, #T_9212c_row1_col3, #T_9212c_row2_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9212c_row0_col3 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_9212c_row1_col1 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_9212c_row1_col2, #T_9212c_row5_col4 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_9212c_row1_col4 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_9212c_row2_col0 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_9212c_row2_col2 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_9212c_row2_col3 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_9212c_row2_col4 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_9212c_row3_col0 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_9212c_row3_col1, #T_9212c_row11_col0, #T_9212c_row12_col0, #T_9212c_row13_col4, #T_9212c_row15_col3, #T_9212c_row20_col0, #T_9212c_row21_col0, #T_9212c_row22_col0, #T_9212c_row26_col0, #T_9212c_row27_col0, #T_9212c_row29_col0, #T_9212c_row31_col0, #T_9212c_row36_col0, #T_9212c_row37_col0, #T_9212c_row44_col0, #T_9212c_row46_col0, #T_9212c_row47_col0, #T_9212c_row48_col0, #T_9212c_row50_col0, #T_9212c_row51_col0, #T_9212c_row52_col0, #T_9212c_row53_col0, #T_9212c_row55_col0, #T_9212c_row56_col0, #T_9212c_row57_col0, #T_9212c_row59_col0, #T_9212c_row60_col0, #T_9212c_row62_col0, #T_9212c_row63_col0, #T_9212c_row64_col0, #T_9212c_row65_col0, #T_9212c_row66_col0, #T_9212c_row68_col0, #T_9212c_row69_col0, #T_9212c_row70_col0, #T_9212c_row71_col0, #T_9212c_row72_col0, #T_9212c_row76_col0, #T_9212c_row79_col0, #T_9212c_row80_col0, #T_9212c_row81_col0, #T_9212c_row87_col0, #T_9212c_row88_col0, #T_9212c_row91_col0, #T_9212c_row92_col0, #T_9212c_row93_col0, #T_9212c_row98_col0, #T_9212c_row100_col0 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_9212c_row3_col2 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_9212c_row3_col3 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_9212c_row3_col4 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_9212c_row4_col0 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_9212c_row4_col1, #T_9212c_row104_col3 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_9212c_row4_col2, #T_9212c_row13_col3, #T_9212c_row16_col0, #T_9212c_row34_col3 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_9212c_row4_col3 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_9212c_row4_col4, #T_9212c_row15_col2 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_9212c_row5_col0 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T
212c_row73_col1, #T_9212c_row73_col2, #T_9212c_row74_col1, #T_9212c_row74_col2, #T_9212c_row75_col1, #T_9212c_row75_col2, #T_9212c_row76_col1, #T_9212c_row76_col2, #T_9212c_row77_col1, #T_9212c_row77_col2, #T_9212c_row78_col1, #T_9212c_row78_col2, #T_9212c_row79_col1, #T_9212c_row79_col2, #T_9212c_row80_col1, #T_9212c_row80_col2, #T_9212c_row81_col1, #T_9212c_row81_col2, #T_9212c_row82_col0, #T_9212c_row82_col1, #T_9212c_row83_col2, #T_9212c_row84_col1, #T_9212c_row85_col1, #T_9212c_row85_col2, #T_9212c_row86_col1, #T_9212c_row86_col2, #T_9212c_row87_col1, #T_9212c_row87_col2, #T_9212c_row88_col1, #T_9212c_row88_col2, #T_9212c_row89_col1, #T_9212c_row89_col2, #T_9212c_row90_col1, #T_9212c_row90_col2, #T_9212c_row91_col1, #T_9212c_row92_col1, #T_9212c_row92_col2, #T_9212c_row93_col1, #T_9212c_row93_col2, #T_9212c_row94_col1, #T_9212c_row94_col2, #T_9212c_row95_col1, #T_9212c_row95_col2, #T_9212c_row96_col1, #T_9212c_row96_col2, #T_9212c_row97_col1, #T_9212c_row97_col2, #T_9212c_row98_col1, #T_9212c_row98_col2, #T_9212c_row99_col1, #T_9212c_row99_col2, #T_9212c_row100_col1, #T_9212c_row100_col2, #T_9212c_row101_col1, #T_9212c_row101_col2, #T_9212c_row102_col1, #T_9212c_row102_col2, #T_9212c_row103_col1, #T_9212c_row103_col2, #T_9212c_row104_col1, #T_9212c_row104_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_9212c_row5_col2, #T_9212c_row8_col3, #T_9212c_row18_col3, #T_9212c_row19_col3, #T_9212c_row20_col3, #T_9212c_row22_col3, #T_9212c_row23_col3, #T_9212c_row24_col3, #T_9212c_row25_col3, #T_9212c_row29_col3, #T_9212c_row32_col3, #T_9212c_row33_col3, #T_9212c_row35_col3, #T_9212c_row37_col3, #T_9212c_row38_col3, #T_9212c_row39_col3, #T_9212c_row41_col3, #T_9212c_row42_col3, #T_9212c_row43_col3, #T_9212c_row44_col3, #T_9212c_row46_col3, #T_9212c_row47_col3, #T_9212c_row48_col3, #T_9212c_row51_col3, #T_9212c_row52_col3, #T_9212c_row55_col3, #T_9212c_row56_col3, #T_9212c_row57_col3, #T_9212c_row58_col3, #T_9212c_row60_col3, #T_9212c_row61_col3, #T_9212c_row64_col3, #T_9212c_row66_col3, #T_9212c_row69_col2, #T_9212c_row70_col3, #T_9212c_row71_col3, #T_9212c_row72_col3, #T_9212c_row74_col3, #T_9212c_row75_col3, #T_9212c_row77_col3, #T_9212c_row81_col3, #T_9212c_row88_col3, #T_9212c_row98_col3, #T_9212c_row99_col3, #T_9212c_row100_col3, #T_9212c_row103_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_9212c_row5_col3 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_9212c_row6_col0, #T_9212c_row73_col0 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_9212c_row6_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_9212c_row6

# %%
# grad_tables["option+stock_return"]

# %% [markdown]
# ## INFO MASTER THESIS
# #### ORANGE / GREEN COLORS WERE MADE MANUALLY IN LATEX
